# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("pib.csv")

# %%
df.head()
# Out:
#    Unnamed: 0 Country Name Country Code      1961      1962      1963  \
# 0           0        Aruba          ABW       NaN       NaN       NaN
# 1           1          NaN          AFE  0.418605  7.937089  5.624317
# 2           2   Afganistán          AFG       NaN       NaN       NaN
# 3           3          NaN          AFW  1.869593  3.726016  7.038172
# 4           4       Angola          AGO       NaN       NaN       NaN
#
#        1964      1965      1966      1967  ...      2016      2017      2018  \
# 0       NaN       NaN       NaN       NaN  ...  1.234335  3.493430  3.212471
# 1  4.650349  5.138153  4.827568  5.338803  ...  2.292501  2.678863  2.706207
# 2       NaN       NaN       NaN       NaN  ...  2.260314  2.647003  1.189228
# 3  5.364580  4.105660 -1.512959 -8.966324  ...  0.176172  2.302761  2.899954
# 4       NaN       NaN       NaN       NaN  ... -0.233077 -0.164689 -0.506698
#
#        2019       2020       2021       2022      2023      2024      2025
# ...

# %%
print("Filas:", df.shape[0])
print("Columnas:", df.shape[1])
# Out:
# Filas: 265
# Columnas: 68

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 265 entries, 0 to 264
# Data columns (total 68 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    265 non-null    int64
#  1   Country Name  263 non-null    object
#  2   Country Code  265 non-null    object
#  3   1961          144 non-null    float64
#  4   1962          151 non-null    float64
#  5   1963          151 non-null    float64
#  6   1964          151 non-null    float64
#  7   1965          151 non-null    float64
#  8   1966          154 non-null    float64
#  9   1967          158 non-null    float64
#  10  1968          160 non-null    float64
#  11  1969          160 non-null    float64
#  12  1970          160 non-null    float64
#  13  1971          184 non-null    float64
#  14  1972          184 non-null    float64
#  15  1973          184 non-null    float64
#  16  1974          184 non-null    float64
# ...

# %%
df = df.drop(columns=["Unnamed: 0"])

# %%
#La columna Unnamed: 0 corresponde únicamente al índice del archivo CSV y no aporta información para el análisis.

# %%
df.isnull().sum()
# Out:
# Country Name      2
# Country Code      0
# 1961            121
# 1962            114
# 1963            114
#                ...
# 2021              8
# 2022              9
# 2023             14
# 2024             19
# 2025             33
# Length: 67, dtype: int64

# %%
completitud = (df.notnull().sum()/len(df))*100

completitud
# Out:
# Country Name     99.245283
# Country Code    100.000000
# 1961             54.339623
# 1962             56.981132
# 1963             56.981132
#                    ...
# 2021             96.981132
# 2022             96.603774
# 2023             94.716981
# 2024             92.830189
# 2025             87.547170
# Length: 67, dtype: float64

# %%
df.describe()
# Out:
#              1961        1962        1963        1964        1965        1966  \
# count  144.000000  151.000000  151.000000  151.000000  151.000000  154.000000
# mean     3.711533    5.267800    5.097775    6.349847    5.807434    4.669488
# std      5.758218    5.137095    5.690930    5.539904    5.612730    4.470478
# min    -27.270000  -19.685042  -12.278657  -12.464993  -12.481834   -7.659066
# 25%      1.597109    3.228230    3.040598    4.322304    3.271553    1.998720
# 50%      4.351548    4.892652    4.999694    6.310748    5.293863    4.775702
# 75%      6.078469    6.849886    7.040123    8.152542    7.391315    7.155391
# max     22.849095   32.524641   35.020377   45.071694   42.410414   19.200000
#
#              1967        1968        1969        1970  ...        2016  \
# count  158.000000  160.000000  160.000000  160.000000  ...  257.000000
# mean     4.097703    6.169154    6.742303    6.576591  ...    3.065658
# ...

# %%
df.isnull().sum(axis=1)
# Out:
# 0      27
# 1       1
# 2      41
# 3       1
# 4      20
#        ..
# 260    48
# 261    37
# 262     0
# 263     0
# 264     0
# Length: 265, dtype: int64

# %%
promedio = df.iloc[:,2:].mean()

promedio
# Out:
# 1961    3.711533
# 1962    5.267800
# 1963    5.097775
# 1964    6.349847
# 1965    5.807434
#           ...
# 2021    5.756946
# 2022    4.493787
# 2023    3.410908
# 2024    3.256921
# 2025    3.615978
# Length: 65, dtype: float64

# %%
promedio.plot(figsize=(12,5))
# Out:
# <Axes: >

# %%
#Imputacíon: "Se detectaron valores faltantes principalmente en los primeros años y en el año 2025. Estos corresponden a datos históricos no reportados por algunos países, por lo que no fueron imputados para evitar alterar el comportamiento real del conjunto de datos."
